# %%
exp = [ [1],[3],[3.5],[4],[6.5],[10]]
salary = [25000,31000,34000,42000,68000,100000]

# %%
import matplotlib.pyplot as plt
plt.scatter(exp,salary)
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
m1_model = LinearRegression()
m1_model
# Out:
# LinearRegression()

# %%
exp
# Out:
# [[1], [3], [3.5], [4], [6.5], [10]]

# %%
salary
# Out:
# [25000, 31000, 34000, 42000, 68000, 100000]

# %%
m1_model.fit(exp,salary)
# Out:
# LinearRegression()

# %%
m1_model.predict([[16]])
# Out:
# array([151658.86287625])

# %%
print('welome to salary calcuation')
print('----------------------------------')
yr = int(input('Enter the nuber of year you worked: '))
print('Your predicted salary for',yr,'year is',round(m1_model.predict([[yr]])[0]))
# Out:
# welome to salary calcuation
# ----------------------------------
# Enter the nuber of year you worked: 6
# Your predicted salary for 6 year is 61960
