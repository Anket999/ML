# %% [markdown]
# <a href="https://colab.research.google.com/github/Anket999/ML/blob/main/Linear_Regration_on_EXP_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Salary_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X=data.iloc[:,:-1].values
X
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y=data.iloc[:,-1].values
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33)

# %%
X_train[:2]
# Out:
# array([[6. ],
#        [1.5]])

# %%
len(X_test)+len(X_train)
# Out:
# 30

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict([[4.9]])
c=model.intercept_
m=model.coef_

# %%
m*4.9+c
# Out:
# array([72498.40701578])

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([ 72498.40701578,  56619.23365672,  64091.78582569, 100520.47764942,
#        103322.68471279,  45410.40540326,  74366.54505802, 116399.65100849,
#         61289.57876233])

# %%
df = pd.DataFrame({'Actual:':y_test,'Predicted:':y_pred})
df
# Out:
#     Actual:     Predicted:
# 0   67938.0   72498.407016
# 1   64445.0   56619.233657
# 2   56957.0   64091.785826
# 3  101302.0  100520.477649
# 4  113812.0  103322.684713
# 5   43525.0   45410.405403
# 6   66029.0   74366.545058
# 7  112635.0  116399.651008
# 8   57189.0   61289.578762

# %%
X_test
# Out:
# array([[4.9],
#        [3.2],
#        [4. ],
#        [7.9],
#        [8.2],
#        [2. ],
#        [5.1],
#        [9.6],
#        [3.7]])

# %%
print('Accuracy is:',model.score(X_train,y_train)*100)
# Out:
# Accuracy is: 96.34000965429479

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X_train,y_train,color='red',label='train')
plt.plot(X_test,y_pred,color='k',label='test')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()

# %%
df['error']=df['Actual:']-df['Predicted:']
df
# Out:
#     Actual:     Predicted:         error
# 0   67938.0   72498.407016  -4560.407016
# 1   64445.0   56619.233657   7825.766343
# 2   56957.0   64091.785826  -7134.785826
# 3  101302.0  100520.477649    781.522351
# 4  113812.0  103322.684713  10489.315287
# 5   43525.0   45410.405403  -1885.405403
# 6   66029.0   74366.545058  -8337.545058
# 7  112635.0  116399.651008  -3764.651008
# 8   57189.0   61289.578762  -4100.578762
